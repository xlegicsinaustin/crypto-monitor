# %%
import pandas as pd 
import sqlalchemy as sql
import unicorn_binance_websocket_api as unicorn

# %%
#defining engine
engine = sql.create_engine('sqlite:///Liveprice.db')

# %%
df = pd.read_sql('MATICUSDT',engine)
df
# Out:
#                 timestamp   price
# 0 2022-10-24 22:50:37.336  0.8969
# 1 2022-10-24 22:50:39.568  0.8970
# 2 2022-10-24 22:50:42.510  0.8973

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import seaborn as sns

# %%
def animate(i):
    data = pd.read_sql('MATICUSDT',engine)
    plt.cla() #clears the axis on refresh
    plt.plot(data.timestamp,data.price, color='g') #price
    plt.axhline(y=data.price.mean(),color='b') #rolling mean
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.title('MATICUSDT')
    plt.gcf().autofmt_xdate()
    plt.tight_layout()

# %%
sns.set_style('darkgrid')

# %%
ani = animation.FuncAnimation(plt.gcf(),animate,100)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df
# Out:
#                     timestamp   price
# 0     2022-08-12 02:05:20.562  0.9185
# 1     2022-08-12 02:05:25.563  0.9184
# 2     2022-08-12 02:05:27.721  0.9179
# 3     2022-08-12 02:05:31.095  0.9179
# 4     2022-08-12 02:05:34.708  0.9180
# ...                       ...     ...
# 32370 2022-10-24 20:58:36.423  0.8974
# 32371 2022-10-24 20:58:39.084  0.8972
# 32372 2022-10-24 20:58:43.084  0.8972
# 32373 2022-10-24 20:58:48.031  0.8971
# 32374 2022-10-24 20:58:53.201  0.8972
#
# [32375 rows x 2 columns]
