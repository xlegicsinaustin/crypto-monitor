# %%
import pandas as pd 
from sqlalchemy import create_engine
import unicorn_binance_websocket_api as unicorn

# %%
#defining engine
engine = create_engine('sqlite:///Liveprice.db')

# %%
df = pd.read_sql('BTCUSDT',engine)
df
# Out:
#                   timestamp     price
# 0   2022-08-11 03:48:32.652  24350.87
# 1   2022-08-11 03:48:34.679  24351.69
# 2   2022-08-11 03:48:36.683  24357.04
# 3   2022-08-11 03:48:38.988  24355.00
# 4   2022-08-11 03:48:40.990  24355.39
# ..                      ...       ...
# 926 2022-08-11 04:20:04.149  24367.87
# 927 2022-08-11 04:20:06.328  24369.30
# 928 2022-08-11 04:20:08.354  24366.76
# 929 2022-08-11 04:20:10.381  24365.79
# 930 2022-08-11 04:20:12.403  24365.71
#
# [931 rows x 2 columns]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import seaborn as sns

# %%
def animate(i):
    data = pd.read_sql('BTCUSDT',engine)
    plt.cla() #clears the axis on refresh
    plt.plot(data.timestamp,data.price, color='g') #price
    plt.axhline(y=data.price.mean(),color='b') #rolling mean
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.title('BTCUSDT')
    plt.gcf().autofmt_xdate()
    plt.tight_layout()

# %%
sns.set_style('darkgrid')

# %%
ani = animation.FuncAnimation(plt.gcf(),animate,100)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
